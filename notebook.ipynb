# %%
import requests
import json

API_KEY = "api_key"
API_URL = "https://api.featherless.ai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

payload = {
    "model": "deepseek-ai/DeepSeek-V3-0324",
    "messages": [
        {
            "role": "system",
            "content": "Tu es un assistant de gestion du temps. Réponds uniquement en JSON."
        },
        {
            "role": "user",
            "content": "Planifie ma journée avec 2h de deep work et 3 réunions."
        }
    ],
    "temperature": 0.3,
    "max_tokens": 512
}

response = requests.post(API_URL, headers=headers, data=json.dumps(payload))

if response.status_code == 200:
    result = response.json()
    print(result["choices"][0]["message"]["content"])
else:
    print("Erreur:", response.status_code, response.text)
# Out:
# ```json
# {
#   "journee": {
#     "matin": {
#       "08:00 - 08:30": "Petit-déjeuner et préparation de la journée",
#       "08:30 - 10:30": "Session de deep work (2h)",
#       "10:30 - 10:45": "Pause-café"
#     },
#     "midi": {
#       "12:00 - 13:00": "Déjeuner"
#     },
#     "apres_midi": {
#       "13:00 - 14:00": "Réunion 1",
#       "14:00 - 15:00": "Réunion 2",
#       "15:00 - 15:15": "Pause",
#       "15:15 - 16:15": "Réunion 3",
#       "16:15 - 17:00": "Tâches administratives ou emails"
#     },
#     "soir": {
#       "17:00 - 17:30": "Revue de la journée et planification du lendemain",
#       "17:30": "Fin de la journée de travail"
#     }
#   }
# }
# ```
